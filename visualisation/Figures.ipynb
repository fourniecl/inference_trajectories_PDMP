# %%
import numpy as np
import csv
import pandas as pd
from general_function import *
import matplotlib.pyplot as plt
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/cfournie/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/cfournie/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/cfournie/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
# ...

# %%
Diff_sch=pd.read_csv("Results_files/Diff_sch.txt",sep=' ',header=None)
PDMP_sch=pd.read_csv("Results_files/PDMP_sch.txt",sep=' ',header=None)
K_sch=pd.read_csv("Results_files/K_sch.txt",sep=' ',header=None)

entroptimegap1G=pd.read_csv("Results_files/Entropybytimegap_1GENE.csv")

entroptimegap_st=pd.read_csv("Results_files/Entropybytimegap_st.csv")
entroptimegap_tr=pd.read_csv("Results_files/Entropybytimegap_tr.csv")

entropnbcell=pd.read_csv("Results_files/Entropybycellumber.csv")

entroptimegapmetriq_tr=pd.read_csv("Results_files/Entropybytimegap_metrics_tr.csv")

entroptimegap_PDMPs_tr=pd.read_csv("Results_files/Entropybytimegap_PDMPs_tr.csv")      

entroptimegap_RNA_tr=pd.read_csv("Results_files/Entropybytimegap_RNA_tr.csv")            

entroptimegap_GRNs=pd.read_csv("Results_files/Entropybytimegap_GRNs_tr.csv")            

entroptimegap_rep=pd.read_csv("Results_files/Entropybytimegap_repressilator.csv")            
entroptimegap_123=pd.read_csv("Results_files/Entropybytimegap_123.csv")


t1_st=40
t1_tr=0.1

# %%
graph_traj("RESULTS_FILES/trajectoires.csv")

# %%
plot_process(Diff_sch,PDMP_sch,K_sch)

# %%
graph1G(entroptimegap1G,t1_tr)

# %%
#graph(entroptimegap_st,t1_st)      
#graph(entroptimegap_tr,t1_tr) 
grapht2t1(entroptimegap_st,t1_st,"$t_{2,st}-t_{1,st}$")      
grapht2t1(entroptimegap_tr,t1_tr,"$t_{2}-t_{1}$")

# %%
graph_nbcell(entropnbcell)

# %%
graph_metrics(entroptimegapmetriq_tr,t1_tr,"$t_{2}-t_{1}$")

# %%
#graph_PDMPs(entroptimegap_PDMPs_st,t1_st,"$t_{2,st}-t_{1,st}$")      
graph_PDMPs(entroptimegap_PDMPs_tr,t1_tr,"$t_{2}-t_{1}$")

# %%
#grapht2t1(entroptimegap_RNA_st,t1_st,"$t_{2,st}-t_{1,st}$")         
grapht2t1(entroptimegap_RNA_tr,t1_tr,"$t_{2}-t_{1}$")

# %%
graph_GRNs(entroptimegap_GRNs,t1_tr,"$t_{2}-t_{1}$")

# %%
grapht2t1(entroptimegap_rep,t1_tr,"$t_{2}-t_{1}$")

# %%
grapht2t1(entroptimegap_123,t1_tr,"$t_{2}-t_{1}$")
