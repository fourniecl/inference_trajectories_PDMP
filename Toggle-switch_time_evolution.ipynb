# %%
import numpy as np
import csv
import pandas as pd
from general_function import *
import matplotlib.pyplot as plt
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.1.3 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/home/cfournie/anaconda3/lib/python3.11/site-packages/ipykernel_launcher.py", line 17, in <module>
#     app.launch_new_instance()
#   File "/home/cfournie/anaconda3/lib/python3.11/site-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/home/cfournie/anaconda3/lib/python3.11/site-packages/ipykernel/kernelapp.py", line 736, in start
# ...

# %%
##################PARAMETERS#############
n = 40
k_on_1, k_on_2 = 5, 5
d_M_1, d_M_2 = 10, 10
d_P_1, d_P_2 = 5, 5
s_1, s_2 = 10, 10
pa_1, pa_2 = 10, 10
pi_1, pi_2 = -10, -10
parameters = [k_on_1, k_on_2, d_M_1, d_M_2, d_P_1, d_P_2, s_1, s_2, pa_1, pa_2, pi_1, pi_2]

G = 2
div=10
tms = np.linspace(0, 5, 100*div)
t1 = 10*div
t2 = 12*div

CI=(0,0)
#########################SIMULATIONS##############
S = simu(n, toggle_switch(G, parameters), CI, tms)
mu, nu = distribution(S, t1, t2)[2:]
Diff_sch=np.loadtxt("RESULTS_FILES/Diff_sch.txt")
PDMP_sch=np.loadtxt("RESULTS_FILES/PDMP_sch.txt")
K_sch=np.loadtxt("RESULTS_FILES/K_sch.txt")

# %%
#Protein (top) and mRNA (bottom) temporal evolution on the toggle switch example. Protein and mRNA levels of the first gene are in blue and protein and mRNA levels of the second gene are in orange.

basic_plot(S[0],G)

# %%
plot_distrib(mu,nu)
